# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import json
import requests as req

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = req.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQBz0kU2i1Spd2f49Fg953Xa9GQW_UDoHoQwGrKoPYSPxdUNLyWkuVDZ0BIY6OzdN6sjbG-QQlKNr-xsDyfefY0iTq2BHM-it0IWpqu4191odPQ2IsU',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
access_token
# Out:
# 'BQBz0kU2i1Spd2f49Fg953Xa9GQW_UDoHoQwGrKoPYSPxdUNLyWkuVDZ0BIY6OzdN6sjbG-QQlKNr-xsDyfefY0iTq2BHM-it0IWpqu4191odPQ2IsU'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI
related_artist_url=base_url+'artists/{artist_id}/related-artists' #de la documentacion
top_tracks_url=base_url+'artists/{artist_id}/top-tracks?country=US'  
headers = {"Authorization": "Bearer " + access_token }
# Out:
# <Response [200]>

# %%
def related_artist(e):
    e=artist_id
    ra = req.get(related_artist_url.format(artist_id=artist_id), headers= headers)
    info=ra.json()
    artists_id= [artist["id"] for artist in info["artists"]]
    artists_name= [artist["name"] for artist in info["artists"]]
    return artists_id

# %%
def top_tracks(artist_id):
    tt=req.get(top_tracks_url.format(artist_id=artist_id), headers= headers)
    info=tt.json()
    tracks= [track["name"] for track in info["tracks"]]
    return tracks

# %%
related_artist_is_list=related_artist("0L8ExT028jH3ddEcZwqJJ5")
related_artist_is_list
# Out:
# ['2UazAtjfzqBF0Nho2awK4z',
#  '5xUf6j4upBrXZPg6AI4MRK',
#  '0iHb0mCbqZTYeb4y9Pirrd',
#  '64tNsm6TnZe2zpcMVMOoHL',
#  '0XHiH53dHrvbwfjYM7en7I',
#  '0mXTJETA4XUa12MmmXxZJh',
#  '2ziB7fzrXBoh1HUPS6sVFn',
#  '78SHxLdtysAXgywQ4vE0Oa',
#  '40Yq4vzPs9VNUrIBG5Jr2i',
#  '6GbCJZrI318Ybm8mY36Of5',
#  '5sD1ZLf2dGQ9gQ3YJl1eAd',
#  '02NfyD6AlLA12crYzw5YcR',
#  '2d0hyoQ5ynDBnkvAbJKORj',
#  '4iudEcmuPlYNdbP3e1bdn1',
#  '7jy3rLJdDQY21OgRLCZ9sD',
#  '4pejUc4iciQfgdX6OKulQn',
#  '3YcBF2ttyueytpXtEzn1Za',
#  '7CHilrn81OdYjkh4uSVnYM',
#  '3R6c2tWDBeYB1GncjLMn9n',
#  '6eoJpTIlcuxJNjV5fDzDJH']

# %%
top_tracks_list=[]

for artist in related_artist_is_list: 
    top_tracks_list.append(top_tracks(artist)) 
    
top_tracks_list
# Out:
# [['Interstate Love Song - 2019 Remaster',
#   'Plush - 2017 Remaster',
#   'Creep - 2017 Remaster',
#   'Vasoline - 2019 Remaster',
#   'Sex Type Thing - 2017 Remaster',
#   'Plush - Acoustic',
#   "Trippin' on a Hole in a Paper Heart",
#   'Big Empty - 2019 Remaster',
#   'Dead & Bloated',
#   'Wicked Garden - 2017 Remaster'],
#  ['Black Hole Sun',
#   'Spoonman',
#   'Fell On Black Days',
#   'Rusty Cage - Remastered',
#   'Outshined - Remastered',
#   'Burden In My Hand',
#   'The Day I Tried To Live',
#   'Pretty Noose',
#   'Blow Up The Outside World',
#   'My Wave'],
#  ['Hunger Strike',
#   'Hunger Strike - 25th Anniversary Mix',
#   'Say Hello 2 Heaven',
#   'Call Me A Dog',
#   'Say Hello 2 Heaven - 25th Anniversary Mix',
#   "Pushin' Forward Back",
#   'Times Of Trouble',
#   'All Night Thing',
#   'Wooden Jesus',
#   'Reach Down'],
#  ['Man in the Box',
#   'Would? (2022 Remaster)',
#   'Nutshell',
#   'Rooster (2022 Remaster)',
#   'Them Bones (2022 Remaster)',
#   'Down In A Hole (2022 Remaster)',
#   'We Die Young',
#   'No Excuses',
#   'I Stay Away',
#   'Rotten Apple'],
#  ['You Know My Name - From "Casino Royale" Soundtrack',
#   'Patience',
#   'Nothing Compares 2 U - Live At SiriusXM/2015',
#   'Nearly Forgot My Broken Heart',
#   'Seasons',
#   'Billie Jean',
#   'Black Hole Sun - Recorded Live At Red Robinson Show Theatre, Vancouver, Canada on April 30, 2011',
#   'Like A Stone - Recorded Live At Queen Elizabeth Theatre, Toronto, ON on April 20, 2011',
#   "Can't Change Me",
#   'Thank You - Recorded Live At Esplanade Arts & Heritage Centre, Medicine Hat, Alberta, Canada on April 27, 2011'],
#  ['Society',
#   'Hard Sun',
#   'Long Nights',
#   'Guaranteed',
#   'No Ceiling',
#   'Rise',
#   'Toulumne',
#   'Setting Forth',
#   "My Father's Daughter",
#   'Throw Your Arms Around Me'],
#  ['Like a Stone',
#   'Show Me How to Live',
#   'Be Yourself',
#   'Cochise',
#   'I Am the Highway',
#   "Doesn't Remind Me",
#   'Gasoline',
#   'What You Are',
#   'Shadow on the Sun',
#   'Sound Of A Gun'],
#  ['Glycerine',
#   'Machinehead',
#   'Comedown',
#   'Swallowed',
#   'Everything Zen',
#   'The Chemicals Between Us',
#   'Little Things',
#   'Glycerine - Acoustic',
#   'The Sound of Winter',
#   'Flowers On A Grave'],
#  ['1979 - Remastered 2012',
#   'Bullet With Butterfly Wings - Remastered 2012',
#   'Disarm - 2011 Remaster',
#   'Zero - Remastered 2012',
#   'Today - 2011 Remaster',
#   'Tonight, Tonight - Remastered 2012',
#   'Cherub Rock - 2011 Remaster',
#   'Mayonaise - 2011 Remaster',
#   'Luna - 2011 Remaster',
#   'Today'],
#  ['Epic',
#   'Easy',
#   'Midlife Crisis',
#   'We Care a Lot',
#   'Ashes to Ashes - 2016 Remaster',
#   'Falling to Pieces',
#   'Evidence - 2016 Remaster',
#   'From Out of Nowhere',
#   'A Small Victory',
#   'The Gentle Art of Making Enemies'],
#  ['No Rain',
#   'Change',
#   'Toes Across The Floor',
#   'Tones Of Home',
#   'The Pusher',
#   'Skinned',
#   'Mouthful Of Cavities',
#   'Soul One',
#   'Galaxie / Hello, Goodbye',
#   'Galaxie - 2002 Digital Remaster / 24 Bit Mastering'],
#  ['Jane Says',
#   'Been Caught Stealing',
#   'Just Because',
#   'Mountain Song',
#   'Stop',
#   'Irresistible Force',
#   'True Nature',
#   'Summertime Rolls',
#   'Ocean Size',
#   'Three Days'],
#  ['Killing In The Name',
#   'Bulls On Parade',
#   'Guerrilla Radio',
#   'Sleep Now In the Fire',
#   'Bombtrack',
#   'Renegades Of Funk',
#   'People of the Sun',
#   'Testify',
#   'Know Your Enemy',
#   'Wake Up'],
#  ['Tomorrow',
#   'Freak',
#   'Straight Lines',
#   'Miss You Love',
#   "Ana's Song (Open Fire)",
#   "Israel's Son",
#   'Tomorrow',
#   'Suicidal Dream',
#   'Anthem for the Year 2000',
#   'Shade'],
#  ['Everlong',
#   'The Pretender',
#   'Learn to Fly',
#   'Best of You',
#   'My Hero',
#   'All My Life',
#   'Times Like These',
#   'Monkey Wrench',
#   'Walk',
#   'Everlong - Acoustic Version'],
#  ['No One Knows',
#   'Go With The Flow',
#   'Little Sister',
#   'Make It Wit Chu',
#   'I Sat by the Ocean',
#   'Song For The Dead',
#   "You Think I Ain't Worth A Dollar, But I Feel Like A Millionaire",
#   "3's & 7's",
#   'The Lost Art Of Keeping A Secret',
#   'First It Giveth'],
#  ['Drive',
#   'Wish You Were Here',
#   'Pardon Me',
#   'Stellar',
#   'Dig',
#   'Anna Molly',
#   'Are You In?',
#   'Nice to Know You',
#   'Love Hurts',
#   'Echo'],
#  ['Slither',
#   'Fall to Pieces',
#   'Dirty Little Thing',
#   'She Builds Quick Machines',
#   'Sucker Train Blues',
#   'The Last Fight',
#   'Let It Roll',
#   'Loving The Alien',
#   'Do It For The Kids',
#   'Set Me Free'],
#  ['Far Behind',
#   'You',
#   'Cover Me',
#   'Change',
#   'Blossom',
#   "Don't You",
#   'Stand',
#   '10,000 Horses',
#   'Breathe Me In',
#   'Rain'],
#  ['Lightning Crashes',
#   'I Alone',
#   'All Over You',
#   'Selling The Drama',
#   "The Dolphin's Cry",
#   "Lakini's Juice",
#   'Overcome',
#   'Run To The Water',
#   'Pain Lies On The Riverside',
#   'Heaven']]

# %%
def related_artist_name(artist_id):
    info=ra.json()
    artists_name= [artist["name"] for artist in info["artists"]]
    return artists_name

# %%
c= related_artist_name("0L8ExT028jH3ddEcZwqJJ5")
c
# Out:
# ['Stone Temple Pilots',
#  'Soundgarden',
#  'Temple Of The Dog',
#  'Alice In Chains',
#  'Chris Cornell',
#  'Eddie Vedder',
#  'Audioslave',
#  'Bush',
#  'The Smashing Pumpkins',
#  'Faith No More',
#  'Blind Melon',
#  "Jane's Addiction",
#  'Rage Against The Machine',
#  'Silverchair',
#  'Foo Fighters',
#  'Queens of the Stone Age',
#  'Incubus',
#  'Velvet Revolver',
#  'Candlebox',
#  'Live']

# %%
playlist1=dict(zip(related_artist_is_list,top_tracks_list))
playlist1
# Out:
# {'2UazAtjfzqBF0Nho2awK4z': ['Interstate Love Song - 2019 Remaster',
#   'Plush - 2017 Remaster',
#   'Creep - 2017 Remaster',
#   'Vasoline - 2019 Remaster',
#   'Sex Type Thing - 2017 Remaster',
#   'Plush - Acoustic',
#   "Trippin' on a Hole in a Paper Heart",
#   'Big Empty - 2019 Remaster',
#   'Dead & Bloated',
#   'Wicked Garden - 2017 Remaster'],
#  '5xUf6j4upBrXZPg6AI4MRK': ['Black Hole Sun',
#   'Spoonman',
#   'Fell On Black Days',
#   'Rusty Cage - Remastered',
#   'Outshined - Remastered',
#   'Burden In My Hand',
#   'The Day I Tried To Live',
#   'Pretty Noose',
#   'Blow Up The Outside World',
#   'My Wave'],
#  '0iHb0mCbqZTYeb4y9Pirrd': ['Hunger Strike',
#   'Hunger Strike - 25th Anniversary Mix',
#   'Say Hello 2 Heaven',
#   'Call Me A Dog',
#   'Say Hello 2 Heaven - 25th Anniversary Mix',
#   "Pushin' Forward Back",
#   'Times Of Trouble',
#   'All Night Thing',
#   'Wooden Jesus',
#   'Reach Down'],
#  '64tNsm6TnZe2zpcMVMOoHL': ['Man in the Box',
#   'Would? (2022 Remaster)',
#   'Nutshell',
#   'Rooster (2022 Remaster)',
#   'Them Bones (2022 Remaster)',
#   'Down In A Hole (2022 Remaster)',
#   'We Die Young',
#   'No Excuses',
#   'I Stay Away',
#   'Rotten Apple'],
#  '0XHiH53dHrvbwfjYM7en7I': ['You Know My Name - From "Casino Royale" Soundtrack',
#   'Patience',
#   'Nothing Compares 2 U - Live At SiriusXM/2015',
#   'Nearly Forgot My Broken Heart',
#   'Seasons',
#   'Billie Jean',
#   'Black Hole Sun - Recorded Live At Red Robinson Show Theatre, Vancouver, Canada on April 30, 2011',
#   'Like A Stone - Recorded Live At Queen Elizabeth Theatre, Toronto, ON on April 20, 2011',
#   "Can't Change Me",
#   'Thank You - Recorded Live At Esplanade Arts & Heritage Centre, Medicine Hat, Alberta, Canada on April 27, 2011'],
#  '0mXTJETA4XUa12MmmXxZJh': ['Society',
#   'Hard Sun',
#   'Long Nights',
#   'Guaranteed',
#   'No Ceiling',
#   'Rise',
#   'Toulumne',
#   'Setting Forth',
#   "My Father's Daughter",
#   'Throw Your Arms Around Me'],
#  '2ziB7fzrXBoh1HUPS6sVFn': ['Like a Stone',
#   'Show Me How to Live',
#   'Be Yourself',
#   'Cochise',
#   'I Am the Highway',
#   "Doesn't Remind Me",
#   'Gasoline',
#   'What You Are',
#   'Shadow on the Sun',
#   'Sound Of A Gun'],
#  '78SHxLdtysAXgywQ4vE0Oa': ['Glycerine',
#   'Machinehead',
#   'Comedown',
#   'Swallowed',
#   'Everything Zen',
#   'The Chemicals Between Us',
#   'Little Things',
#   'Glycerine - Acoustic',
#   'The Sound of Winter',
#   'Flowers On A Grave'],
#  '40Yq4vzPs9VNUrIBG5Jr2i': ['1979 - Remastered 2012',
#   'Bullet With Butterfly Wings - Remastered 2012',
#   'Disarm - 2011 Remaster',
#   'Zero - Remastered 2012',
#   'Today - 2011 Remaster',
#   'Tonight, Tonight - Remastered 2012',
#   'Cherub Rock - 2011 Remaster',
#   'Mayonaise - 2011 Remaster',
#   'Luna - 2011 Remaster',
#   'Today'],
#  '6GbCJZrI318Ybm8mY36Of5': ['Epic',
#   'Easy',
#   'Midlife Crisis',
#   'We Care a Lot',
#   'Ashes to Ashes - 2016 Remaster',
#   'Falling to Pieces',
#   'Evidence - 2016 Remaster',
#   'From Out of Nowhere',
#   'A Small Victory',
#   'The Gentle Art of Making Enemies'],
#  '5sD1ZLf2dGQ9gQ3YJl1eAd': ['No Rain',
#   'Change',
#   'Toes Across The Floor',
#   'Tones Of Home',
#   'The Pusher',
#   'Skinned',
#   'Mouthful Of Cavities',
#   'Soul One',
#   'Galaxie / Hello, Goodbye',
#   'Galaxie - 2002 Digital Remaster / 24 Bit Mastering'],
#  '02NfyD6AlLA12crYzw5YcR': ['Jane Says',
#   'Been Caught Stealing',
#   'Just Because',
#   'Mountain Song',
#   'Stop',
#   'Irresistible Force',
#   'True Nature',
#   'Summertime Rolls',
#   'Ocean Size',
#   'Three Days'],
#  '2d0hyoQ5ynDBnkvAbJKORj': ['Killing In The Name',
#   'Bulls On Parade',
#   'Guerrilla Radio',
#   'Sleep Now In the Fire',
#   'Bombtrack',
#   'Renegades Of Funk',
#   'People of the Sun',
#   'Testify',
#   'Know Your Enemy',
#   'Wake Up'],
#  '4iudEcmuPlYNdbP3e1bdn1': ['Tomorrow',
#   'Freak',
#   'Straight Lines',
#   'Miss You Love',
#   "Ana's Song (Open Fire)",
#   "Israel's Son",
#   'Tomorrow',
#   'Suicidal Dream',
#   'Anthem for the Year 2000',
#   'Shade'],
#  '7jy3rLJdDQY21OgRLCZ9sD': ['Everlong',
#   'The Pretender',
#   'Learn to Fly',
#   'Best of You',
#   'My Hero',
#   'All My Life',
#   'Times Like These',
#   'Monkey Wrench',
#   'Walk',
#   'Everlong - Acoustic Version'],
#  '4pejUc4iciQfgdX6OKulQn': ['No One Knows',
#   'Go With The Flow',
#   'Little Sister',
#   'Make It Wit Chu',
#   'I Sat by the Ocean',
#   'Song For The Dead',
#   "You Think I Ain't Worth A Dollar, But I Feel Like A Millionaire",
#   "3's & 7's",
#   'The Lost Art Of Keeping A Secret',
#   'First It Giveth'],
#  '3YcBF2ttyueytpXtEzn1Za': ['Drive',
#   'Wish You Were Here',
#   'Pardon Me',
#   'Stellar',
#   'Dig',
#   'Anna Molly',
#   'Are You In?',
#   'Nice to Know You',
#   'Love Hurts',
#   'Echo'],
#  '7CHilrn81OdYjkh4uSVnYM': ['Slither',
#   'Fall to Pieces',
#   'Dirty Little Thing',
#   'She Builds Quick Machines',
#   'Sucker Train Blues',
#   'The Last Fight',
#   'Let It Roll',
#   'Loving The Alien',
#   'Do It For The Kids',
#   'Set Me Free'],
#  '3R6c2tWDBeYB1GncjLMn9n': ['Far Behind',
#   'You',
#   'Cover Me',
#   'Change',
#   'Blossom',
#   "Don't You",
#   'Stand',
#   '10,000 Horses',
#   'Breathe Me In',
#   'Rain'],
#  '6eoJpTIlcuxJNjV5fDzDJH': ['Lightning Crashes',
#   'I Alone',
#   'All Over You',
#   'Selling The Drama',
#   "The Dolphin's Cry",
#   "Lakini's Juice",
#   'Overcome',
#   'Run To The Water',
#   'Pain Lies On The Riverside',
#   'Heaven']}

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus
url=base_url+'/users/{user_id}/playlists'
playlist1.post(url.)

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
